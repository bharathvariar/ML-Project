# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("../data/dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Task 1

# %%
#returns a new modified dataframe and does not change the input dataframe.
def feature1(data):
    data1 = data.copy()
    mean = np.mean(data1, axis=0)
    for i in range(2,data1.shape[1]):
        data1.iloc[:,i].fillna(mean[i-1], inplace=True)
    return data1

# %%
df1 = feature1(df)
# Out:
# /Users/kanika/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("old values:", df.iloc[533][2], df.iloc[548][4])
print("new replaced values:", df1.iloc[533][2], df1.iloc[548][4])
# Out:
# old values: nan nan
# new replaced values: 14.116125 92.02346830985915

# %% [markdown]
# # Task 2

# %%
#does not change the input dataframe.
#input the training dataframe without dropping any columns.
#returns X data, Y labels, mean, standard deviation.
#you can use mean and stddev to normalize test data if you have to, otherwise remove it from return.
def feature2(data):
    data1 = data.copy()
    y = data1['diagnosis']
    x = data1.drop(['diagnosis'], axis=1)
    mean = np.mean(x, axis=0)
    stddev = np.std(x, axis=0)
    x = (x - mean) / stddev
    return x, y, mean, stddev

# %%
df2, y, mean, stddev = feature2(df)

# %%
df2
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   -0.236405     1.102422     -2.073335        1.268389   0.984375
# 1   -0.236403     1.836635     -0.353632        1.684639   1.908708
# 2    0.431741     1.586206      0.456187        1.565122   1.558884
# 3    0.432121    -0.767260      0.253732       -0.595257  -0.764464
# 4    0.432201     1.756953     -1.151816        1.775308   1.826229
# ..        ...          ...           ...             ...        ...
# 564 -0.235732     2.118368      0.721473        2.059677   2.343856
# 565 -0.235730     1.711420      2.085134        1.614577   1.723842
# 566 -0.235727     0.706858      2.045574        0.670803   0.577953
# 567 -0.235725     1.845172      2.336457        1.981372   1.735218
# 568 -0.242406    -1.808817      1.221792       -1.817631  -1.347789
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object
